# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix
import warnings
import seaborn as sns
import matplotlib.pyplot as plt

# Suppress warnings for cleaner output
warnings.filterwarnings("ignore")

# Load your dataset
from ucimlrepo import fetch_ucirepo  # Replace with actual data loading if needed
heart_disease = fetch_ucirepo(id=45)  # Cleveland Heart Disease dataset

# Data (as pandas DataFrames)
X = heart_disease.data.features
y = heart_disease.data.targets

# Combine features and target
df = pd.concat([X, y], axis=1)

# Assign column names if necessary
column_names = [
    'age', 'sex', 'cp', 'trestbps', 'chol', 'fbs',
    'restecg', 'thalach', 'exang', 'oldpeak',
    'slope', 'ca', 'thal', 'num'
]
df.columns = column_names

# Handle Missing Values
df.replace(['?', ''], np.nan, inplace=True)
df = df.apply(pd.to_numeric, errors='coerce')
for col in ['ca', 'thal', 'oldpeak', 'slope']:
    df[col].fillna(df[col].median(), inplace=True)

# Simplify 'num' to binary classification
df['target'] = df['num'].apply(lambda x: 1 if x > 0 else 0)
df.drop('num', axis=1, inplace=True)

# Convert 'ca' and 'thal' to integer type before encoding
df['ca'] = df['ca'].astype(int)
df['thal'] = df['thal'].astype(int)

# One-Hot Encoding for categorical variables
categorical_cols = ['cp', 'restecg', 'slope', 'thal', 'ca']
df = pd.get_dummies(df, columns=categorical_cols, drop_first=True)

# Separate features and target variable
X = df.drop('target', axis=1).values
y = df['target'].values

# Standardize the features
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Define the dataset class
class HeartDiseaseDataset(Dataset):
    def __init__(self, features, targets):
        self.features = torch.tensor(features, dtype=torch.float32)
        self.labels = torch.tensor(targets, dtype=torch.float32)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]

# Define the neural network model
class KNNInspiredNN(nn.Module):
    def __init__(self, input_size):
        super(KNNInspiredNN, self).__init__()
        self.layers = nn.Sequential(
            nn.Linear(input_size, 64),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(32, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.layers(x)

# Set up K-Fold Cross-Validation
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
fold_results = []

# Training parameters
num_epochs = 50
batch_size = 16
patience = 10
learning_rate = 0.001

for fold, (train_idx, val_idx) in enumerate(kf.split(X, y)):
    print(f"Starting fold {fold+1}/{kf.n_splits}")

    # Split data for this fold
    X_train, X_val = X[train_idx], X[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]
    
    # Create datasets and dataloaders
    train_dataset = HeartDiseaseDataset(X_train, y_train)
    val_dataset = HeartDiseaseDataset(X_val, y_val)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size)

    # Initialize model, criterion, optimizer
    model = KNNInspiredNN(input_size=X_train.shape[1])
    criterion = nn.BCELoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    # Early stopping variables
    best_val_loss = float('inf')
    patience_counter = 0
    best_model_state = None
    train_losses = []
    val_losses = []

    # Training loop
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        for features, labels in train_loader:
            optimizer.zero_grad()
            outputs = model(features).squeeze()
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item() * features.size(0)
        epoch_loss = running_loss / len(train_loader.dataset)
        train_losses.append(epoch_loss)

        # Validation phase
        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for features, labels in val_loader:
                outputs = model(features).squeeze()
                loss = criterion(outputs, labels)
                val_loss += loss.item() * features.size(0)
        val_loss /= len(val_loader.dataset)
        val_losses.append(val_loss)

        print(f"Fold {fold+1}, Epoch [{epoch+1}/{num_epochs}], Train Loss: {epoch_loss:.4f}, Val Loss: {val_loss:.4f}")

        # Early stopping
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            patience_counter = 0
            best_model_state = model.state_dict()  # Save the best model state
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print("Early stopping triggered")
                break

    # Plot Training and Validation Losses for this fold
    plt.figure(figsize=(8, 6))
    plt.plot(train_losses, label='Train Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title(f'Training and Validation Loss for Fold {fold+1}')
    plt.legend()
    plt.show()

    # Load the best model for evaluation
    model.load_state_dict(best_model_state)

    # Evaluation on validation set
    model.eval()
    with torch.no_grad():
        y_pred_prob = model(torch.tensor(X_val, dtype=torch.float32)).squeeze().numpy()
        y_pred = (y_pred_prob >= 0.5).astype(int)

    # Collect results for this fold
    report = classification_report(y_val, y_pred, output_dict=True)
    report_df = pd.DataFrame(report).transpose()
    fold_results.append(report_df)

    # Display confusion matrix for this fold
    cm = confusion_matrix(y_val, y_pred)
    plt.figure(figsize=(5, 4))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False, square=True)
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title(f'Confusion Matrix for Fold {fold+1}')
    plt.show()

# Calculate average results across all folds
average_results = pd.concat(fold_results).groupby(level=0).mean()
print("\nAverage Cross-Validation Results:")
print(average_results.round(2))
# Out:
# Starting fold 1/5
# Fold 1, Epoch [1/50], Train Loss: 0.6955, Val Loss: 0.6732
# Fold 1, Epoch [2/50], Train Loss: 0.6711, Val Loss: 0.6498
# Fold 1, Epoch [3/50], Train Loss: 0.6407, Val Loss: 0.6198
# Fold 1, Epoch [4/50], Train Loss: 0.6200, Val Loss: 0.5875
# Fold 1, Epoch [5/50], Train Loss: 0.5757, Val Loss: 0.5433
# Fold 1, Epoch [6/50], Train Loss: 0.5534, Val Loss: 0.5007
# Fold 1, Epoch [7/50], Train Loss: 0.5214, Val Loss: 0.4570
# Fold 1, Epoch [8/50], Train Loss: 0.4708, Val Loss: 0.4105
# Fold 1, Epoch [9/50], Train Loss: 0.4584, Val Loss: 0.3791
# Fold 1, Epoch [10/50], Train Loss: 0.4048, Val Loss: 0.3606
# Fold 1, Epoch [11/50], Train Loss: 0.4024, Val Loss: 0.3408
# Fold 1, Epoch [12/50], Train Loss: 0.3777, Val Loss: 0.3260
# Fold 1, Epoch [13/50], Train Loss: 0.3837, Val Loss: 0.3160
# Fold 1, Epoch [14/50], Train Loss: 0.3762, Val Loss: 0.3124
# Fold 1, Epoch [15/50], Train Loss: 0.3729, Val Loss: 0.3118
# Fold 1, Epoch [16/50], Train Loss: 0.3763, Val Loss: 0.3067
# Fold 1, Epoch [17/50], Train Loss: 0.4074, Val Loss: 0.3057
# Fold 1, Epoch [18/50], Train Loss: 0.3626, Val Loss: 0.3031
# Fold 1, Epoch [19/50], Train Loss: 0.3928, Val Loss: 0.3047
# Fold 1, Epoch [20/50], Train Loss: 0.3541, Val Loss: 0.3133
# Fold 1, Epoch [21/50], Train Loss: 0.3359, Val Loss: 0.3101
# Fold 1, Epoch [22/50], Train Loss: 0.3346, Val Loss: 0.3131
# Fold 1, Epoch [23/50], Train Loss: 0.2991, Val Loss: 0.3157
# Fold 1, Epoch [24/50], Train Loss: 0.3370, Val Loss: 0.3124
# Fold 1, Epoch [25/50], Train Loss: 0.3291, Val Loss: 0.3191
# Fold 1, Epoch [26/50], Train Loss: 0.3185, Val Loss: 0.3172
# Fold 1, Epoch [27/50], Train Loss: 0.3285, Val Loss: 0.3119
# Fold 1, Epoch [28/50], Train Loss: 0.3349, Val Loss: 0.3038
# Early stopping triggered
# Starting fold 2/5
# Fold 2, Epoch [1/50], Train Loss: 0.6754, Val Loss: 0.6543
# Fold 2, Epoch [2/50], Train Loss: 0.6564, Val Loss: 0.6345
# Fold 2, Epoch [3/50], Train Loss: 0.6192, Val Loss: 0.6034
# Fold 2, Epoch [4/50], Train Loss: 0.5963, Val Loss: 0.5624
# Fold 2, Epoch [5/50], Train Loss: 0.5653, Val Loss: 0.5237
# Fold 2, Epoch [6/50], Train Loss: 0.5159, Val Loss: 0.4887
# Fold 2, Epoch [7/50], Train Loss: 0.4554, Val Loss: 0.4574
# Fold 2, Epoch [8/50], Train Loss: 0.4105, Val Loss: 0.4390
# Fold 2, Epoch [9/50], Train Loss: 0.4268, Val Loss: 0.4326
# Fold 2, Epoch [10/50], Train Loss: 0.4111, Val Loss: 0.4313
# Fold 2, Epoch [11/50], Train Loss: 0.3674, Val Loss: 0.4339
# Fold 2, Epoch [12/50], Train Loss: 0.3710, Val Loss: 0.4369
# Fold 2, Epoch [13/50], Train Loss: 0.3462, Val Loss: 0.4409
# Fold 2, Epoch [14/50], Train Loss: 0.3458, Val Loss: 0.4407
# Fold 2, Epoch [15/50], Train Loss: 0.3553, Val Loss: 0.4461
# Fold 2, Epoch [16/50], Train Loss: 0.3418, Val Loss: 0.4482
# Fold 2, Epoch [17/50], Train Loss: 0.3180, Val Loss: 0.4551
# Fold 2, Epoch [18/50], Train Loss: 0.3096, Val Loss: 0.4589
# Fold 2, Epoch [19/50], Train Loss: 0.2695, Val Loss: 0.4674
# Fold 2, Epoch [20/50], Train Loss: 0.3391, Val Loss: 0.4773
# Early stopping triggered
# Starting fold 3/5
# Fold 3, Epoch [1/50], Train Loss: 0.6994, Val Loss: 0.6747
# Fold 3, Epoch [2/50], Train Loss: 0.6780, Val Loss: 0.6472
# Fold 3, Epoch [3/50], Train Loss: 0.6302, Val Loss: 0.6167
# Fold 3, Epoch [4/50], Train Loss: 0.5992, Val Loss: 0.5805
# Fold 3, Epoch [5/50], Train Loss: 0.5552, Val Loss: 0.5343
# Fold 3, Epoch [6/50], Train Loss: 0.5057, Val Loss: 0.4807
# Fold 3, Epoch [7/50], Train Loss: 0.4705, Val Loss: 0.4395
# Fold 3, Epoch [8/50], Train Loss: 0.4401, Val Loss: 0.4113
# Fold 3, Epoch [9/50], Train Loss: 0.4077, Val Loss: 0.3896
# Fold 3, Epoch [10/50], Train Loss: 0.4039, Val Loss: 0.3780
# Fold 3, Epoch [11/50], Train Loss: 0.3996, Val Loss: 0.3713
# Fold 3, Epoch [12/50], Train Loss: 0.3923, Val Loss: 0.3699
# Fold 3, Epoch [13/50], Train Loss: 0.3441, Val Loss: 0.3680
# Fold 3, Epoch [14/50], Train Loss: 0.3330, Val Loss: 0.3667
# Fold 3, Epoch [15/50], Train Loss: 0.3409, Val Loss: 0.3670
# Fold 3, Epoch [16/50], Train Loss: 0.3444, Val Loss: 0.3680
# Fold 3, Epoch [17/50], Train Loss: 0.3207, Val Loss: 0.3715
# Fold 3, Epoch [18/50], Train Loss: 0.3137, Val Loss: 0.3717
# Fold 3, Epoch [19/50], Train Loss: 0.2945, Val Loss: 0.3709
# Fold 3, Epoch [20/50], Train Loss: 0.2851, Val Loss: 0.3710
# Fold 3, Epoch [21/50], Train Loss: 0.3236, Val Loss: 0.3750
# Fold 3, Epoch [22/50], Train Loss: 0.3184, Val Loss: 0.3730
# Fold 3, Epoch [23/50], Train Loss: 0.3007, Val Loss: 0.3756
# Fold 3, Epoch [24/50], Train Loss: 0.2890, Val Loss: 0.3761
# Early stopping triggered
# Starting fold 4/5
# Fold 4, Epoch [1/50], Train Loss: 0.6762, Val Loss: 0.6601
# Fold 4, Epoch [2/50], Train Loss: 0.6419, Val Loss: 0.6305
# Fold 4, Epoch [3/50], Train Loss: 0.6197, Val Loss: 0.5930
# Fold 4, Epoch [4/50], Train Loss: 0.5812, Val Loss: 0.5440
# Fold 4, Epoch [5/50], Train Loss: 0.5492, Val Loss: 0.4901
# Fold 4, Epoch [6/50], Train Loss: 0.5038, Val Loss: 0.4421
# Fold 4, Epoch [7/50], Train Loss: 0.4540, Val Loss: 0.4099
# Fold 4, Epoch [8/50], Train Loss: 0.3888, Val Loss: 0.3909
# Fold 4, Epoch [9/50], Train Loss: 0.4170, Val Loss: 0.3790
# Fold 4, Epoch [10/50], Train Loss: 0.3665, Val Loss: 0.3742
# Fold 4, Epoch [11/50], Train Loss: 0.3979, Val Loss: 0.3744
# Fold 4, Epoch [12/50], Train Loss: 0.3763, Val Loss: 0.3726
# Fold 4, Epoch [13/50], Train Loss: 0.3535, Val Loss: 0.3728
# Fold 4, Epoch [14/50], Train Loss: 0.3244, Val Loss: 0.3743
# Fold 4, Epoch [15/50], Train Loss: 0.3807, Val Loss: 0.3710
# Fold 4, Epoch [16/50], Train Loss: 0.3205, Val Loss: 0.3686
# Fold 4, Epoch [17/50], Train Loss: 0.3232, Val Loss: 0.3698
# Fold 4, Epoch [18/50], Train Loss: 0.2959, Val Loss: 0.3729
# Fold 4, Epoch [19/50], Train Loss: 0.3221, Val Loss: 0.3731
# Fold 4, Epoch [20/50], Train Loss: 0.2965, Val Loss: 0.3773
# Fold 4, Epoch [21/50], Train Loss: 0.3223, Val Loss: 0.3800
# Fold 4, Epoch [22/50], Train Loss: 0.2845, Val Loss: 0.3840
# Fold 4, Epoch [23/50], Train Loss: 0.2785, Val Loss: 0.3865
# Fold 4, Epoch [24/50], Train Loss: 0.2896, Val Loss: 0.3879
# Fold 4, Epoch [25/50], Train Loss: 0.3135, Val Loss: 0.3889
# Fold 4, Epoch [26/50], Train Loss: 0.2817, Val Loss: 0.3879
# Early stopping triggered
# Starting fold 5/5
# Fold 5, Epoch [1/50], Train Loss: 0.6956, Val Loss: 0.6696
# Fold 5, Epoch [2/50], Train Loss: 0.6676, Val Loss: 0.6368
# Fold 5, Epoch [3/50], Train Loss: 0.6454, Val Loss: 0.5953
# Fold 5, Epoch [4/50], Train Loss: 0.6031, Val Loss: 0.5480
# Fold 5, Epoch [5/50], Train Loss: 0.5578, Val Loss: 0.4967
# Fold 5, Epoch [6/50], Train Loss: 0.5086, Val Loss: 0.4511
# Fold 5, Epoch [7/50], Train Loss: 0.4730, Val Loss: 0.4117
# Fold 5, Epoch [8/50], Train Loss: 0.4233, Val Loss: 0.3843
# Fold 5, Epoch [9/50], Train Loss: 0.4070, Val Loss: 0.3679
# Fold 5, Epoch [10/50], Train Loss: 0.3815, Val Loss: 0.3623
# Fold 5, Epoch [11/50], Train Loss: 0.3897, Val Loss: 0.3623
# Fold 5, Epoch [12/50], Train Loss: 0.3502, Val Loss: 0.3591
# Fold 5, Epoch [13/50], Train Loss: 0.3775, Val Loss: 0.3624
# Fold 5, Epoch [14/50], Train Loss: 0.3408, Val Loss: 0.3603
# Fold 5, Epoch [15/50], Train Loss: 0.3417, Val Loss: 0.3644
# Fold 5, Epoch [16/50], Train Loss: 0.3424, Val Loss: 0.3639
# Fold 5, Epoch [17/50], Train Loss: 0.3711, Val Loss: 0.3665
# Fold 5, Epoch [18/50], Train Loss: 0.3336, Val Loss: 0.3671
# Fold 5, Epoch [19/50], Train Loss: 0.3445, Val Loss: 0.3654
# Fold 5, Epoch [20/50], Train Loss: 0.3298, Val Loss: 0.3709
# Fold 5, Epoch [21/50], Train Loss: 0.3272, Val Loss: 0.3701
# Fold 5, Epoch [22/50], Train Loss: 0.3286, Val Loss: 0.3682
# Early stopping triggered
# Average Cross-Validation Results:
#               precision  recall  f1-score  support
# 0                  0.85    0.88      0.87    32.80
# 1                  0.86    0.82      0.84    27.80
# accuracy           0.85    0.85      0.85     0.85
# macro avg          0.86    0.85      0.85    60.60
# weighted avg       0.86    0.85      0.85    60.60
